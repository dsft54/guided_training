# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# <b> Глеб, привет!👋</b>
#
# Меня зовут Кирилл Васильев, мы уже встречались на проекте «Линейные модели». Рад снова быть ревьюером твоей работы!
#
# Я буду оставлять комментарии в твоем проекте. Пожалуйста, не удаляй их, они могут быть полезны в случае повторной проверки.
#
# Свои комментарии я буду обозначать <font color='green'>зеленым</font>, <font color='gold'>желтым</font> и <font color='red'>красным</font> цветами, например:
#
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> В случае, если решение на отдельном шаге является полностью правильным. Здесь же я могу давать советы и предложения.
# </div>
#
# <br/>
#
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b> В случае, когда решение на отдельном шаге станет еще лучше, если внести небольшие коррективы.
# </div>
#
#
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
#  В случае, когда решение на отдельном шаге требует существенной переработки и внесения правок. Напоминаю, что проект не может быть принят с первого раза, если ревью содержит комментарии, рекомендующие доработать шаги.
# </div>
#
# <br/>
# <div class="alert alert-info">
# Рекомендую для твоих комментариев использовать синий или любой другой цветной фон. Я постараюсь ничего не пропустить, но если комментарии будут выделены, то это мне очень поможет!
# </div>
#
# Увидев у тебя неточность, в первый раз я лишь укажу на ее наличие и дам тебе возможность самостоятельно найти и исправить ее. На реальной работе твой руководитель будет поступать также. Но если ты пока не справишься с такой задачей - при следующей проверке я дам более точную подсказку.

# %% [markdown]
# ## Проект: Обучение с учителем: качество модели

# %% [markdown]
# ## Описание Проекта

# %% [markdown]
#         Интернет-магазин «В один клик» продаёт разные товары: для детей, для дома, мелкую бытовую технику, косметику и даже продукты. Отчёт магазина за прошлый период показал, что активность покупателей начала снижаться. Привлекать новых клиентов уже не так эффективно: о магазине и так знает большая часть целевой аудитории. Возможный выход — удерживать активность постоянных клиентов. Сделать это можно с помощью персонализированных предложений.
#         «В один клик» — современная компания, поэтому её руководство не хочет принимать решения просто так — только на основе анализа данных и бизнес-моделирования. У компании есть небольшой отдел цифровых технологий, и вам предстоит побыть в роли стажёра в этом отделе.
#         Итак, вашему отделу поручили разработать решение, которое позволит персонализировать предложения постоянным клиентам, чтобы увеличить их покупательскую активность.

# %% [markdown]
# ## Описание данных

# %% [markdown]
# 1) market_file.csv - Таблица, которая содержит данные о поведении покупателя на сайте, о коммуникациях с покупателем и его продуктовом поведении.
# * id — номер покупателя в корпоративной базе данных.
# * Покупательская активность — рассчитанный класс покупательской активности (целевой признак): «снизилась» или «прежний уровень».
# * Тип сервиса — уровень сервиса, например «премиум» и «стандарт».
# * Разрешить сообщать — информация о том, можно ли присылать покупателю дополнительные предложения о товаре. Согласие на это даёт покупатель.
# * Маркет_актив_6_мес — среднемесячное значение маркетинговых коммуникаций компании, которое приходилось на покупателя за последние 6 месяцев. Это значение показывает, какое число рассылок, звонков, показов рекламы и прочего приходилось на клиента.
# * Маркет_актив_тек_мес — количество маркетинговых коммуникаций в текущем месяце.
# * Длительность — значение, которое показывает, сколько дней прошло с момента регистрации покупателя на сайте.
# * Акционные_покупки — среднемесячная доля покупок по акции от общего числа покупок за последние 6 месяцев.
# * Популярная_категория — самая популярная категория товаров у покупателя за последние 6 месяцев.
# * Средний_просмотр_категорий_за_визит — показывает, сколько в среднем категорий покупатель просмотрел за визит в течение последнего месяца.
# * Неоплаченные_продукты_штук_квартал — общее число неоплаченных товаров в корзине за последние 3 месяца.
# * Ошибка_сервиса — число сбоев, которые коснулись покупателя во время посещения сайта.
# * Страниц_за_визит — среднее количество страниц, которые просмотрел покупатель за один визит на сайт за последние 3 месяца.
#
# 2) market_money.csv - Таблица с данными о выручке, которую получает магазин с покупателя, то есть сколько покупатель всего потратил за период взаимодействия с сайтом.
# * id — номер покупателя в корпоративной базе данных.
# * Период — название периода, во время которого зафиксирована выручка. Например, 'текущий_месяц' или 'предыдущий_месяц'.
# * Выручка — сумма выручки за период.
#
# 3) market_time.csv - Таблица с данными о времени (в минутах), которое покупатель провёл на сайте в течение периода.
# * id — номер покупателя в корпоративной базе данных.
# * Период — название периода, во время которого зафиксировано общее время.
# * минут — значение времени, проведённого на сайте, в минутах.
#
# 4) money.csv - Таблица с данными о среднемесячной прибыли покупателя за последние 3 месяца: какую прибыль получает магазин от продаж каждому покупателю.
# * id — номер покупателя в корпоративной базе данных.
# * Прибыль — значение прибыли.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Контекст и план проекта понятны.
# </div>

# %% [markdown]
# ## Импорты и глобальные переменные

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import phik
import shap

from scipy.stats import ttest_ind

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, StandardScaler, MinMaxScaler
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.metrics import f1_score, accuracy_score

    
RANDOM_STATE = 666
TEST_SIZE = 0.25
pd.set_option('future.no_silent_downcasting', True)

# %% [markdown]
# ## Шаг 1. Загрузка данных

# %% [markdown]
# ### market_file.csv

# %%
market_file_df = pd.read_csv('datasets/market_file.csv')
market_file_df.info()
market_file_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 13 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   id                                   1300 non-null   int64
#  1   Покупательская активность            1300 non-null   object
#  2   Тип сервиса                          1300 non-null   object
#  3   Разрешить сообщать                   1300 non-null   object
#  4   Маркет_актив_6_мес                   1300 non-null   float64
#  5   Маркет_актив_тек_мес                 1300 non-null   int64
#  6   Длительность                         1300 non-null   int64
#  7   Акционные_покупки                    1300 non-null   float64
#  8   Популярная_категория                 1300 non-null   object
#  9   Средний_просмотр_категорий_за_визит  1300 non-null   int64
#  10  Неоплаченные_продукты_штук_квартал   1300 non-null   int64
# ...

# %% [markdown]
# ### market_money.csv

# %%
market_money_df = pd.read_csv('datasets/market_money.csv')
market_money_df.info()
market_money_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       3900 non-null   int64
#  1   Период   3900 non-null   object
#  2   Выручка  3900 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 91.5+ KB
#        id               Период  Выручка
# 0  215348  препредыдущий_месяц      0.0
# 1  215348        текущий_месяц   3293.1
# 2  215348     предыдущий_месяц      0.0
# 3  215349  препредыдущий_месяц   4472.0
# 4  215349        текущий_месяц   4971.6

# %% [markdown]
# ### market_time.csv

# %%
market_time_df = pd.read_csv('datasets/market_time.csv')
market_time_df.info()
market_time_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2600 entries, 0 to 2599
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      2600 non-null   int64
#  1   Период  2600 non-null   object
#  2   минут   2600 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 61.1+ KB
#        id            Период  минут
# 0  215348     текущий_месяц     14
# 1  215348  предыдцщий_месяц     13
# 2  215349     текущий_месяц     10
# 3  215349  предыдцщий_месяц     12
# 4  215350     текущий_месяц     13

# %% [markdown]
# ### money.csv

# %%
money_df = pd.read_csv('datasets/money.csv', delimiter=';', decimal=',')
money_df.info()
money_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       1300 non-null   int64
#  1   Прибыль  1300 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 20.4 KB
#        id  Прибыль
# 0  215348     0.98
# 1  215349     4.16
# 2  215350     3.13
# 3  215351     4.87
# 4  215352     4.21

# %% [markdown]
# ### Вывод
#     Исходные данные соответствуют описанию, запись данных для money.csv была отлична, это было учтено при чтении данных.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Все верно.
# </div>

# %% [markdown]
# ## Шаг 2. Предобработка данных

# %%
def seek_dub(df):
    print(f'Дубликатов в датафрейме: {df.duplicated().sum()}')
    for col in df.select_dtypes(include='object').columns.to_list():
        print('Уникальные значения колонки', col, df[col].unique())

# %%
market_file_df.columns = [x.replace(' ', '_') for x in market_file_df.columns]
print(market_file_df.columns)
seek_dub(market_file_df)
market_file_df['Тип_сервиса'] = market_file_df['Тип_сервиса'].replace('стандартт', 'стандарт')
# Out:
# Index(['id', 'Покупательская_активность', 'Тип_сервиса', 'Разрешить_сообщать',
#        'Маркет_актив_6_мес', 'Маркет_актив_тек_мес', 'Длительность',
#        'Акционные_покупки', 'Популярная_категория',
#        'Средний_просмотр_категорий_за_визит',
#        'Неоплаченные_продукты_штук_квартал', 'Ошибка_сервиса',
#        'Страниц_за_визит'],
#       dtype='object')
# Дубликатов в датафрейме: 0
# Уникальные значения колонки Покупательская_активность ['Снизилась' 'Прежний уровень']
# Уникальные значения колонки Тип_сервиса ['премиум' 'стандартт' 'стандарт']
# Уникальные значения колонки Разрешить_сообщать ['да' 'нет']
# Уникальные значения колонки Популярная_категория ['Товары для детей' 'Домашний текстиль' 'Косметика и аксесуары'
#  'Техника для красоты и здоровья' 'Кухонная посуда'
#  'Мелкая бытовая техника и электроника']

# %%
seek_dub(market_money_df)
# Out:
# Дубликатов в датафрейме: 0
# Уникальные значения колонки Период ['препредыдущий_месяц' 'текущий_месяц' 'предыдущий_месяц']

# %%
seek_dub(market_time_df)
market_time_df['Период'] = market_time_df['Период'].replace('предыдцщий_месяц', 'предыдущий_месяц')
# Out:
# Дубликатов в датафрейме: 0
# Уникальные значения колонки Период ['текущий_месяц' 'предыдцщий_месяц']

# %%
seek_dub(money_df)
# Out:
# Дубликатов в датафрейме: 0

# %% [markdown]
# ### Вывод
#     Для датафрейма market_file_df пробелы в названии колонок заменены на нижние подчеркивания во избежание путаницы и ошибок с символами. В нем же устранен неявный дубликат для колонки "Тип_сервиса", полученный в результате, предположительно, опечатки.
#     Для датафрейма market_time_df исправлена ошибка в значении "предыдущий_месяц".
#     В остальных датафреймах дубликатов и ошибок не обнаружено.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Замечательно по опечаткам, в остальном данные действительно у нас качественные.
# </div>

# %% [markdown]
# ## Шаг 3. Исследовательский анализ данных

# %% [markdown]
# ### market_file.csv

# %%
market_file_df.info()
market_file_df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 13 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   id                                   1300 non-null   int64
#  1   Покупательская_активность            1300 non-null   object
#  2   Тип_сервиса                          1300 non-null   object
#  3   Разрешить_сообщать                   1300 non-null   object
#  4   Маркет_актив_6_мес                   1300 non-null   float64
#  5   Маркет_актив_тек_мес                 1300 non-null   int64
#  6   Длительность                         1300 non-null   int64
#  7   Акционные_покупки                    1300 non-null   float64
#  8   Популярная_категория                 1300 non-null   object
#  9   Средний_просмотр_категорий_за_визит  1300 non-null   int64
#  10  Неоплаченные_продукты_штук_квартал   1300 non-null   int64
# ...

# %%
nrow, ncol = 4, 2
fig, axes = plt.subplots(nrow, ncol, figsize=(20, 24))
cols = market_file_df.select_dtypes(exclude='object').columns.to_list()
index = 1
for i in range(nrow):
    for j in range(ncol):
        market_file_df.boxplot(column=cols[index], by='Покупательская_активность', ax=axes[i, j])
        axes[i, j].set_title(cols[index])
        index += 1
fig.suptitle('Диаграммы количественных признаков датафрейма market_file с разделением по целевому признаку', fontsize=20, y=1.02)
fig.tight_layout()
plt.show()

# %%
nrow, ncol = 3, 2 
fig, axes = plt.subplots(nrow, ncol, figsize=(16, 12))
cols = market_file_df.select_dtypes(include='object').columns.to_list()
index = 1
for j in range(nrow):
    market_file_df[market_file_df[cols[0]] == 'Снизилась'][cols[index]].value_counts().plot(kind='pie', ax=axes[j, 0], title=cols[index] + ' активность снизилась', autopct='%1.1f%%', ylabel='')
    market_file_df[market_file_df[cols[0]] == 'Прежний уровень'][cols[index]].value_counts().plot(kind='pie', ax=axes[j, 1], title=cols[index] + ' активность прежняя', autopct='%1.1f%%', ylabel='')
    index += 1
fig.suptitle('Диаграммы категориальных признаков датафрейма market_file с разделением по целевому признаку', fontsize=20, y=1.02)
fig.tight_layout()
plt.show()

# %% [markdown]
# #### Вывод
# * Покупательская_активность. Целевой признак. Для него наблюдается небольшой дисбаланс классов, который необходимо учесть при разбиении данных на выборки и обучении моделей;
# * Тип_сервиса. соотношение пользователей отличается для тех, у кого активность снизилась, в такой премиум пользователей больше;
# * Разрешить_сообщать. Преимущественно пользователи согласны на дополнительные предложения магазина, а их соотношение для разных категорий активности практически не отличается;
# * Маркет_актив_6_мес. В среднем на пользователя приходится 4-5 рекламных рассылок в месяц за полгода, для пользователей чья активность снизилась, среднее значения несколько меньше;
# * Маркет_актив_тек_мес. Среднее за текущий месяц не отличается от активности за полгода, и держится на среднем в 4 рассылки, если рассматривать целевые категории пользователей, то для них отличий практически нет;
# * Длительность в выборке. Равномерно представлены пользователи с давностью регистрации на сайте в диапазоне от 100 до 1000 дней, выбросов или ошибок не замечено, а так же время с регистрации не отличается для целевых категорий пользователей;
# * Акционные_покупки. В среднем треть покупок пользователей состоит из товаров со скидкой, тем не менее в выборке представлены пользователи, пользующиеся преимущественно акционными предложиениями. Для пользователей, чья активность снизилась, доля акционных товаров в корзине выше;
# * Популярная_категория. Наиболее популярная категория у покупателей - Товары для детей, в целом, все 6 категорий представлены практически равномерно, однако если магазин продает все, в том числе и продукты, стоит отметить отсутствие популярности этих категорий у пользователей. Для пользователей, чья активность снизилась, детские товары чаще оказываются в любимой категории, чем для тех, у кого она осталась на прежнем уровне практически на 10%;
# * Средний_просмотр_категорий_за_визит. Из 6ти представленных категорий, в среднем просматривают 3. Для тех у кого активность осталась на прежнем уровне среднее выше, чем у тех у кого она снизилась, практически на 2 единицы;
# * Неоплаченные_продукты_штук_квартал. В среднем у пользователя 3 неоплаченных товара в корзине. Среднее для пользователей, у которых снизилась активность больше на 2 единицы;
# * Ошибка_сервиса. В среднем пользователь сталкивается с 4 сбоями при посещении сайта, в данных не указано за какой период, но такой уровень можно назвать достаточно высоким и он мог негативно повлиять на посещаемость сайта магазина. Снижение активности привело к снижению встречаемых пользователем ошибок;
# * Страниц_за_визит. В среднем пользователь открывает 8 страниц на сайте за посещение. Для тех, чья активность снизилась, среднее число посещаемых страниц меньше.
#
#     Пользователи, чья активность снизилась, получают меньше рекламы, встречают меньше ошибок на сайте, имеют большее соотношение премиум подписок к обычным, большее отношение акционных товаров в корзине.

# %% [markdown]
# <div class="alert alert-warning">
# <h2><s> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Я бы здесь посмотрел на гистограммы и сразу в разрезе целевого признака. Так увидим, чем лояльные пользователи отличаются от уходящих.
#
# ***
#
#
# Исследовательский анализ мы делаем для того, чтобы понять, какие закономерности заложены в наших данных. Здесь крайне важно посмотреть на распределения признаков в разрезе целевого признака (снижения активности).
#
# Можно построить и наложить друг на друга гистограммы по данным в подвыборках с и без снижения активности. Можно расположить рядом два боксплота, для категориальных данных − две диаграммы.
#
# Самое банальное и простое: сгруппировать по признаку снижения активности и вывести среднее значение для каждого из признаков. Проанализировать, в каких признаках самые большие различия.
#
# Важно в выводе к исследовательскому анализу дать портрет клиента, снижающего активность: какие признаки говорят о высокой вероятности ухода клиента?
#
#
# В этом проекте аналитическая составляющая достаточно серьезная. Если делаем анализ данных не только для подготовки признаков для моделей, но и для того, чтобы узнать новую информацию о бизнес-процессах, то исследование в разрезе целевого признака − решение по умолчанию.
#
# </div>

# %% [markdown]
# ### market_money.csv

# %%
market_money_df.info()
display(market_money_df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       3900 non-null   int64
#  1   Период   3900 non-null   object
#  2   Выручка  3900 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 91.5+ KB
#                   id        Выручка
# count    3900.000000    3900.000000
# mean   215997.500000    5025.696051
# std       375.325686    1777.704104
# min    215348.000000       0.000000
# 25%    215672.750000    4590.150000
# 50%    215997.500000    4957.500000
# 75%    216322.250000    5363.000000
# max    216647.000000  106862.200000

# %%
display(market_money_df[market_money_df['Выручка'] > 10000])
# Out:
#         id         Период   Выручка
# 98  215380  текущий_месяц  106862.2

# %%
market_money_df.loc[market_money_df['Выручка'] > 100000, ['Выручка']] = market_money_df[market_money_df['Выручка'] > 100000]['Выручка'] - 100000
market_money_df = market_money_df[market_money_df['Выручка'] != 0].groupby('id').filter(lambda x: len(x['Выручка']) == 3)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Верно.
# </div>

# %%
market_money_df.boxplot(by='Период', column=['Выручка'], grid=True, figsize=(10, 10))
# Out:
# <Axes: title={'center': 'Выручка'}, xlabel='Период'>

# %% [markdown]
# #### Вывод
#     Один единственный выброс на 3900 строк данных выглядит подозрительно. Похоже на ошибку порядка при заполнении данных, возможно вручную, тысячи оставляем. Наблюдаем нулевые значения выручки в препредыдущем и предыдущем месяце таких пользователей всего 3, поэтому их исключаем. Для остальных датафреймов исключим этих пользователей после объединения данных. Текущий месяц имеет среднее выше, чем в предыдущие два и не имеет нулевых значений.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Да, все точно.
# </div>

# %% [markdown]
# ### market_time.csv

# %%
market_time_df.info()
market_time_df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2600 entries, 0 to 2599
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      2600 non-null   int64
#  1   Период  2600 non-null   object
#  2   минут   2600 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 61.1+ KB
#                   id        минут
# count    2600.000000  2600.000000
# mean   215997.500000    13.336154
# std       375.349754     4.080198
# min    215348.000000     4.000000
# 25%    215672.750000    10.000000
# 50%    215997.500000    13.000000
# 75%    216322.250000    16.000000
# max    216647.000000    23.000000

# %%
market_time_df.boxplot(by='Период', column=['минут'], grid=True, figsize=(10, 10))
# Out:
# <Axes: title={'center': 'минут'}, xlabel='Период'>

# %% [markdown]
# #### Вывод
#     Количество проведенного времени на сайте не имеет выбросов или ошибок и за месяц практически не изменилось.

# %% [markdown]
# ### money.csv

# %%
money_df.info()
money_df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       1300 non-null   int64
#  1   Прибыль  1300 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 20.4 KB
#                   id      Прибыль
# count    1300.000000  1300.000000
# mean   215997.500000     3.996631
# std       375.421985     1.013722
# min    215348.000000     0.860000
# 25%    215672.750000     3.300000
# 50%    215997.500000     4.045000
# 75%    216322.250000     4.670000
# max    216647.000000     7.430000

# %%
money_df.boxplot(column=['Прибыль'], grid=True, figsize=(10, 10))
# Out:
# <Axes: >

# %% [markdown]
# #### Вывод
#     Значение прибыли представлено в диапазоне от 0.86 до 7,43, предположительно это связано с долей акционных товаров в покупках клиента.

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
#
#
# Важно выше рассмаотреть отдельно лояльных и клиентов со снижающейся активностью. В выводе нужно уточнить, чем одни будут отличаться от других.

# %% [markdown]
# ## Шаг 4. Объединение таблиц

# %%
market_file_df = market_file_df.set_index('id')

# %%
for per in market_money_df['Период'].unique():
    market_file_df['Выручка_за_' + per] = market_money_df[market_money_df['Период'] == per].set_index('id')['Выручка']
for per in market_time_df['Период'].unique():
    market_file_df['Минут_за_' + per] = market_time_df[market_time_df['Период'] == per].set_index('id')['минут']
market_file_df = market_file_df.dropna()
print('Размер сводной таблицы после исключения пользователей с нулями в выручке: ', market_file_df.shape)
market_file_df.head()
# Out:
# Размер сводной таблицы после исключения пользователей с нулями в выручке:  (1297, 17)
#        Покупательская_активность Тип_сервиса Разрешить_сообщать  \
# id
# 215349                 Снизилась     премиум                 да
# 215350                 Снизилась    стандарт                нет
# 215351                 Снизилась    стандарт                 да
# 215352                 Снизилась    стандарт                нет
# 215353                 Снизилась    стандарт                 да
#
#         Маркет_актив_6_мес  Маркет_актив_тек_мес  Длительность  \
# id
# 215349                 4.4                     4           819
# 215350                 4.9                     3           539
# 215351                 3.2                     5           896
# 215352                 5.1                     3          1064
# 215353                 3.3                     4           762
#
#         Акционные_покупки Популярная_категория  \
# id
# 215349               0.75     Товары для детей
# ...

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
#
# Есть еще способ, как в 4-5 строк и отфильтровать активных пользователей, и все объединить.
#
# Используем сводные таблицы, развернув наши таблицы с периодами так, чтобы в строках остались уникальные id, а в столбцах были периоды. Дальше просто отбираем строки, где ни в одном из столбцов нет нулей, после чего просто парой строк объединяем наши три таблицы - они уже все в готовом для этого формате.
#
# </div>

# %% [markdown]
# ## Шаг 5. Корреляционный анализ

# %%
plt.figure(figsize=(14,12))
ax = plt.axes()
correlation = market_file_df.phik_matrix()
sns.heatmap(correlation, annot=True, ax=ax)
ax.set_title('Тепловая карта матрицы корреляции показателей датафрейма')
plt.show()
# Out:
# interval columns not set, guessing: ['Маркет_актив_6_мес', 'Маркет_актив_тек_мес', 'Длительность', 'Акционные_покупки', 'Средний_просмотр_категорий_за_визит', 'Неоплаченные_продукты_штук_квартал', 'Ошибка_сервиса', 'Страниц_за_визит', 'Выручка_за_препредыдущий_месяц', 'Выручка_за_текущий_месяц', 'Выручка_за_предыдущий_месяц', 'Минут_за_текущий_месяц', 'Минут_за_предыдущий_месяц']

# %% [markdown]
# #### Вывод
# * На расчитанную покупательскую активность абсолютно не влияют разрешение пользователя об уведомлениях и значение рекламной рассылки в текущем месяце. При обучении моделей эти признаки можно опустить.
# * На расчитанную покупательскую активность слабо влияют тип сервиса, длительность, выручка за текущий и предудущий месяцы.
# * Наиболее сильное влияние на целевой признак оказывают количество посещенных страниц и минуты за предыдущий месяцю.
# * Мультиколлинеарности между признаками не наблюдается.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Все верно. Ну и минимальный портрет уходящего пользователя добавился. Все равно советую проработать его внимательнее. Обрати внимание на акционные покупки.

# %% [markdown]
# ##  Шаг 6. Использование пайплайнов

# %%
market_file_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1297 entries, 215349 to 216647
# Data columns (total 17 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Покупательская_активность            1297 non-null   object
#  1   Тип_сервиса                          1297 non-null   object
#  2   Разрешить_сообщать                   1297 non-null   object
#  3   Маркет_актив_6_мес                   1297 non-null   float64
#  4   Маркет_актив_тек_мес                 1297 non-null   int64
#  5   Длительность                         1297 non-null   int64
#  6   Акционные_покупки                    1297 non-null   float64
#  7   Популярная_категория                 1297 non-null   object
#  8   Средний_просмотр_категорий_за_визит  1297 non-null   int64
#  9   Неоплаченные_продукты_штук_квартал   1297 non-null   int64
#  10  Ошибка_сервиса                       1297 non-null   int64
# ...

# %%
market_file_df['Покупательская_активность'] = market_file_df['Покупательская_активность'].map({'Снизилась': 1, 'Прежний уровень': 0})

# %% [markdown]
# При разбиении данных учтем неравномерность классов. Для числовых показателей можно не использовать RobustScaler так как выбросов в данных не наблюдается. OrdinalEncoder используем для популярных категорий.

# %% [markdown]
# ### Разбиение данных на тренировочную и тестовую выборки

# %%
X_train, X_test, y_train, y_test = train_test_split(
    market_file_df.drop(['Покупательская_активность', 'Разрешить_сообщать', 'Маркет_актив_тек_мес'], axis=1),
    market_file_df['Покупательская_активность'],
    test_size = TEST_SIZE, 
    random_state = RANDOM_STATE,
    stratify = market_file_df['Покупательская_активность'])

# %% [markdown]
#  <div class="alert alert-block alert-danger">
# <h2><s> Комментарий ревьюера <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>
#
# Давай здесь переведем таргет в численный вид. 1 - если снизилась, 0 - прежний уровень активности. Чтобы дальше не было разночтений по этому показателю.

# %% [markdown]
# ### Подготовка пайплайнов

# %%
ohe_columns = ['Тип_сервиса']
ord_columns = ['Популярная_категория']
num_columns = X_train.select_dtypes(exclude='object').columns.to_list()

ohe_pipe = Pipeline([
        ('simpleImputer_ohe', SimpleImputer(missing_values=np.nan, strategy='most_frequent')),
        ('ohe', OneHotEncoder(drop='first', sparse_output=False))
    ])

ord_pipe = Pipeline([
        ('simpleImputer_before_ord', SimpleImputer(missing_values=np.nan, strategy='most_frequent')),
        ('ord', OrdinalEncoder(
                categories=[['Товары для детей', 'Домашний текстиль', 'Косметика и аксесуары',
                   'Техника для красоты и здоровья', 'Кухонная посуда',
                   'Мелкая бытовая техника и электроника']],
                handle_unknown='use_encoded_value', unknown_value=np.nan
            )
        ),
        ('simpleImputer_adter_ord', SimpleImputer(missing_values=np.nan, strategy='most_frequent')),
    ])

# %%
data_preprocessor = ColumnTransformer(
    [('ohe', ohe_pipe, ohe_columns),
     ('ord', ord_pipe, ord_columns),
     ('num', StandardScaler(), num_columns)
    ], 
    remainder='passthrough'
)

# %%
pipe_final = Pipeline([
    ('preprocessor', data_preprocessor),
    ('models', LogisticRegression(random_state=RANDOM_STATE))
])

# %% [markdown]
# ### Параметры используемых моделей для GridSearchCV

# %%
param_grid = [
    {
        'models': [DecisionTreeClassifier(
            random_state=RANDOM_STATE,
            class_weight='balanced'
            )],
        'models__max_depth': range(1, 11),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  
    },
    {
        'models': [KNeighborsClassifier()],
        'models__n_neighbors': range(3, 11),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']   
    },
    {
        'models': [LogisticRegression( 
            random_state=RANDOM_STATE, 
            class_weight='balanced',
            solver='liblinear', 
            )],
        'models__penalty': ['l1', 'l2'],
        'models__C': range(1, 11),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  
    },
    {
        'models': [SVC(
            random_state=RANDOM_STATE,
            class_weight='balanced',
            probability=True,
            )],
        'models__kernel': ['rbf', 'linear', 'poly'],
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']
    }
]

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Отлично, что используешь `remainder='passthrough'` . Хороший выбор гиперпараметров и значений для подбора. Отлично, что пробуем два типа масштабирования.
# </div>

# %% [markdown]
# Для оценки качества обученной модели используем accuracy, так как для исследования в равной степени важны все виды ошибок.

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Дисбаланс у нас небольшой. Но вообще f1 чувствительная метрика к дисбалансу классов и при нем она будет снижаться (вопрос, полезно ли это нам. Иногда полезно).
#
# Итого: так как дисбаланс конркетно здесь небольшой, то подошли бы все метрики, которые будут учитывать и полноту, и точность. А это у нас три основных: accuracy, F1, ROC_AUC. Соответственно, f1 подходит.

# %% [markdown]
# ### Поиск лучшей модели

# %%
grid_search = GridSearchCV(
    pipe_final, 
    param_grid, 
    cv=5,
    scoring='accuracy',
    n_jobs=-1,
)
grid_search.fit(X_train, y_train)

print('Лучшая модель и её параметры:\n', grid_search.best_estimator_)
print ('Метрика лучшей модели на тренировочной выборке:', grid_search.best_score_)
# Out:
# Лучшая модель и её параметры:
#  Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   Pipeline(steps=[('simpleImputer_ohe',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  sparse_output=False))]),
#                                                   ['Тип_сервиса']),
#                                                  ('ord',
#                                                   Pipeline(steps=[('simpleImputer_before_ord',
# ...

# %%
y_pred = grid_search.best_estimator_.predict(X_test)
print('accuracy_score лучшей модели на тестовых данных:', accuracy_score(y_test, y_pred))
# Out:
# accuracy_score лучшей модели на тестовых данных: 0.8769230769230769

# %% [markdown]
# ### Вывод
#     В результате подбора параметров и поиска лучшей модели, таковой стала SVC c параметром degree равным 2. Ее accuracy_score (доля правильных классификаций модели) на тестовых данных составил 0.88.

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# f1 - среднее гармоническое полноты и точности. Обычно говорят, что метрика сложноинтерпретируемая. Поэтому тут можно немного отчаяться, пытаясь ее представить как « это то, сколько раз наша модель правильно ... ».
#
# ***
#
# `Ее f1_score на тестовых данных составил 0.82 в определении снижения покупальской активности и 0.9 в определении отсутствия изменений.`- я очень сильно неуверен, что это будет удачная формулировка в плане ее понятности для заказчика, хотя понятно, из чего ты исходишь. Ты говоришь, что в одном случае мы посчитали по одному классу, а вдругом поменяли классы местами.
#
# Все-таки правильным будет использовать один подход к описанию классов. F1 - это некоторая метрика, которая учитывает оптимальный баланс полноты и точности.
#
# Считаем по формуле среднего гармонического:
#
# `F1 = 2 * recall * precision / (recall + precision)`
#
# Либо раскладываем на ошибки:
#
# `F1 = 2 * TP / (2 * TP + FP + FN)`
#
# При этом единичкой мы значительно чаще обозначаем либо более редкий класс, либо факт чего-либо, либо факт изменения чего-либо. В нашем случае единичка это факт снижения активонсти.
#
# ***
#
# Очень похоже на accuracy, там мы тоже в знаменателе минимизируем все ошибки (FP + FN), но нормируемся на верные предсказания:
#
# `accuracy = TP + TN / (TP + TN + FP + FN)`
#
# Тогда отличие будет в том, что в f1 мы как бы пристальнее смотрим именно на объекты положительного класса.
#
# </div>

# %% [markdown]
# ## Шаг 7. Анализ важности признаков

# %% [markdown]
# ### Инициализация данных для SHAP

# %%
best_model = grid_search.best_estimator_

X_train_transformed = best_model[0].transform(X_train) 
X_train_transformed = pd.DataFrame(X_train_transformed, columns=best_model[0].get_feature_names_out())

sampled_data = shap.sample(X_train_transformed, nsamples=40, random_state=RANDOM_STATE)

explainer = shap.KernelExplainer(best_model[1].predict_proba, sampled_data)

# %%
shap_values = explainer(sampled_data)
# Out:
#   0%|          | 0/40 [00:00<?, ?it/s]

# %% [markdown]
# ### Влияние значения показателя на его принадлежность к классу

# %%
shap.plots.beeswarm(shap_values[:,:,0], max_display=len(X_train_transformed.columns))

# %% [markdown]
# ### Значимость показателя для модели

# %%
shap.plots.bar(shap_values[:,:,0], max_display=16)

# %% [markdown]
# ### Вывод
#     Определяющим фактором для определения снизится ли активность покупателя является его взаимодействие с сайтом магазина. Количество посещенных страниц за визит, а также количество категорий товаров оказывают влияние на целевой признак. Тип любимой категории в отдельности слабо влияет на возможность снижения активности пользователя, а выручка от его покупок слабо определяет его активность. Самые малозначимые признаки - это тип сервиса, количество ошибок и время с регистрации на сайте. Для повышения активности пользователей можно:
#     * Переработать систему подписки на сервис. Ее влияние сейчас незначительно;
#     * Повысить заинтересованность пользователя в других категориях товаров, введя, например для них специальные предложения.

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Количество времени, проводимое на сайте − это просто индикатор заинтересованности в покупках, но не причина активности в покупках. Примерно как значок недостатка топлива в баке не является причиной остановки автомобиля, хотя и коррелирует с фактом остановки.
#
#
# ****
#
# Это как в магазине количество покупок будет очень сильно коррелировать с числом зашедших покупателей и средним временем, которое покупатель проводит в магазине. Но просить покупателей зайти и выйти по три раза или подольше не уходить из магазина, чтобы увеличить формальное количество заходов в магазин или длительность нахождения точно не стоит, на покупки это не повлияет.
#
#
# В количестве посещенных страниц кроме интереса пользователей может быть фактор удобства сайта, но для его оценки у нас нет данных (глубина просмотров, клики, рекомендации − всего этого нам не положили в датасет), поэтому здесь и анализировать это не будем. Будем считать, что вклад удобства сайта для нас неопределим.
#
# ***
#
# `Ввести поощерения для самых преданных покупателей магазина с давней регистрацией;` - а это из чего вытекает? И как это повысит прибыль? Здесь нужно развить мысль. Пока предположительно с тобой можно не согласиться.
#
#
# Возможно, не стоит тратить ресурсы на удержание тех, кто и так не собирается уходить?
#
# Подробнее на эту тему можно почитать здесь: https://habr.com/ru/companies/ru_mts/articles/485980/
#
#
# </div>

# %% [markdown]
# ## Шаг 8. Сегментация покупателей

# %%
X_entire = best_model[0].transform(market_file_df.drop(['Покупательская_активность', 'Разрешить_сообщать', 'Маркет_актив_тек_мес'], axis=1))
y_prob = best_model[1].predict_proba(X_entire)[:,1]

# %%
market_file_df['Вероятность_снижения_активности'] = y_prob
market_file_df['Среднемесячная_прибыль_от_покупателя_за_последние_3_месяца'] = money_df.set_index('id')['Прибыль']
market_file_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1297 entries, 215349 to 216647
# Data columns (total 20 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   Покупательская_активность                                   1297 non-null   int64
#  1   Тип_сервиса                                                 1297 non-null   object
#  2   Разрешить_сообщать                                          1297 non-null   object
#  3   Маркет_актив_6_мес                                          1297 non-null   float64
#  4   Маркет_актив_тек_мес                                        1297 non-null   int64
#  5   Длительность                                                1297 non-null   int64
#  6   Акционные_покупки                                           1297 non-null   float64
# ...

# %%
ax = sns.scatterplot(data=market_file_df, 
                     x='Выручка_за_текущий_месяц',
                     y='Вероятность_снижения_активности',
                     hue='Средний_просмотр_категорий_за_визит',)
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.title('Диаграмма рассеяния')
plt.show()

# %% [markdown]
# Для исследования отберем группу пользователей чья вероятность снижения активности высока, выручка за текущий месяц составила более 5000, при числе просматриваемых категорий не более 2.

# %%
t_filter = (
    (market_file_df['Вероятность_снижения_активности'] >= 0.8) & 
    (market_file_df['Выручка_за_текущий_месяц'] >= 5000) &
    (market_file_df['Средний_просмотр_категорий_за_визит'] <= 2)
    )
t_df = market_file_df[t_filter]
t_df.info()
t_df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 136 entries, 215354 to 216607
# Data columns (total 20 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   Покупательская_активность                                   136 non-null    int64
#  1   Тип_сервиса                                                 136 non-null    object
#  2   Разрешить_сообщать                                          136 non-null    object
#  3   Маркет_актив_6_мес                                          136 non-null    float64
#  4   Маркет_актив_тек_мес                                        136 non-null    int64
#  5   Длительность                                                136 non-null    int64
#  6   Акционные_покупки                                           136 non-null    float64
# ...

# %%
t_df['Популярная_категория'].value_counts().plot(kind='pie', title='Популярная категория для выбранных покупателей', autopct='%1.1f%%', ylabel='')
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2><s> Комментарий ревьюера <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>
#
# Для сегментации по заданию принципиально нужно взять вероятности класса.
#
# ***
#
# `8.1 Выполните сегментацию покупателей. Используйте результаты моделирования и данные о прибыльности покупателей.`
#
# Попробую описать, что мы должны сделать:
#
# Самое важное − мы должны по заданию выбрать некоторый сегмент пользователей, обосновать выбор сегмента, обосновать то, как мы этот сегмент определяем (почему выбираем такие значения признаков для отбора пользователей в сегмент), а дальше исследовать только этот сегмент.
#
# 1) Под результаты моделирования здесь мы понимаем предсказания нашей модели, то есть, вероятности классов. Мы можем ранжировать клиентов по вероятности снижения активности и таким образом использовать эту информацию как одну из осей скаттерплота (для примера). Второй осью тогда будет какая-то категория, которая будет логичной после выбора сегмента. Например, если выбираем сегмент с высокой вероятностью снижения активности и высокой выручкой, то второй шкалой в скаттерплоте будет выручка.
#
#
# 2) Важно аргументировать выбор границ и для вероятности снижения активности, и для прибыльности. Как раз это будет удобно сделать, солавшись на график (думаю, скаттерплот тут в качестве типа визуализации будет выигрывать).
#
#
# Дальше следует провести исследование для выбранного сегмента: посмотреть на данные в разрезе периодов, в разрезе категорий товаров, акций итд. Нужно выявить факторы, которые сильнее всего влияют на снижение активности и предложить решения для минимизации негативного воздействия этих факторов.
#
# </div>

# %%
nrow, ncol = 6, 2
fig, axes = plt.subplots(nrow, ncol, figsize=(20, 35))
cols = ['Акционные_покупки', 'Выручка_за_текущий_месяц', 'Выручка_за_предыдущий_месяц', 'Выручка_за_препредыдущий_месяц']
row = 0
for cat in t_df['Популярная_категория'].unique():
    t_df[t_df['Популярная_категория'] == cat][cols[0]].plot(kind='box', ax=axes[row, 0], grid=True, ylabel='значение')
    axes[row, 0].set_title('Категория ' + cat)
    t_df[t_df['Популярная_категория'] == cat][cols[1:]].plot(kind='box', ax=axes[row, 1], grid=True, ylabel='значение')
    axes[row, 1].set_title('Категория ' + cat)
    row += 1
fig.suptitle('Диаграммы размаха для доли акционных товаров и выручки с покупателей предпочитающих определенную категорию', fontsize=20, y=1.02)
fig.tight_layout()
plt.show()

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Сейчас смотришь категории по всем периодам. Немного все в кучу. Хорошо бы посмотреть разницу в выручке между периодами для разных категорий. Так увидим, в какой категории динамика выручки положительная, а где - отрицательная. Это очень важная для нас информация, нужно исправлять отрицательную динамику.
#
# </div>

# %% [markdown]
# ### Вывод
#     Для выбранных покупателей наиболее интересной категорией товаров оказалось косметика и аксессуары. При рассмотрении всех категорий товаров по отдельности можно сделать вывод, что даже при ежемесячном увеличении выручки от покупателей, их активность снижается в каждой категории, даже не смотря на долю акционных товаров. Это может означать, что покупателей перестает привлекать либо растущая цена приобретаемых товаров, либо скуднеющий ассортимент. Также их активность может привлекать только акция на их любимую категорию. Определить точно в чем причина невозможно, так как для этого не хватает данных. Заказчик может предоставить дополнительные данные по ассортименту товаров и изменению их стоимости за последние 3 месяца. Это повысит качество и точность исследования.
#
# Для повышения активности покупателей возможно:
# * Поискать поставщиков товаров популярных категорий сопоставимого качества, но меньшей стоимости;
# * Проводить больше акций в категории "Мелкая бытовая техника и электроника";
# * Предлагать персонально акции для менее популярных категорий товаров, для повышения заинтересованности в них.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера #3 <a class="tocSkip"> </h2>
#
# 👍 Согласен.
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Что такое система сервиса и как ее нужно пересмотреть?
#
# Вот представь, что компания на аутсорсе заказала аналитику, заплатила, прилетел отчет, а в нем «пересматривайте систему сервиса». Мы по возможности должны быть чуть более конкретными, чем записки из китайских печенек с предсказаниями.
#
# ***
#
# По первым двум предложениям ок, но выше нужно внимательнее посмотреть на категории, которые у нас проседают в динамике, на популярные категории и уже от этого давать боле конркетные рекомендации, в каких категориях нужно делать оптимизацию. При этом можно просто отметить, что вот у нас есть сегмент, который мы выбрали по принципу, что именно этих людей выгодно удерживать в первую очередь и затраты на удержание этих клиентов окупятся лучше всего.
#
# Тогда для сегмента мы понимаем, что ему интересно, что он покупал по акции и перестал покупать, что нужно доложить, чтобы клиенты не ушли. В рекомендациях важно дать как можно больше конкретики. У нас данные не очень богатые, но кое-что вытащить можно.
#
# Почему я здесь говорю про «ушли», а не «снизили активность». Нужно понимать, что, например, в банке у нас будет факт оттока − клиент разорвал договор. А в маркетплейсе такого события не будет. Мы можем посмотреть, клиенты с какими характеристиками у нас уходят так, что затем в течение года не совершают покупок. И считать достижение такого состояния для клиентов «снижением активности».  Фактически такое снижение активности будет равнозначно оттоку.
#
# Тогда обрати внимание на акционные покупки: клиенты, которые покупают почти все по акции, тратят много денег, выручка по ним выше среднего, однако в некоторый момент (предопложительно синхронно) они массово попадают в снижение активности. Кажется такое поведение необычным?  Возможно, у нас была какая-то акция, по которой они пришли, а когда акция закончилась, они решили, что серсис им неинтересен. Тогда логично этих клиентов подхватить и предложить им что-то интересное.

# %% [markdown]
# ## Шаг 9. Общий вывод
# 1) Для решения задачи необходимо было построить модель, которая предсказывала вероятность снижения покупательской активности, выделить и исследовать определенную категорию покупателя;
# 2) Исходные данные о постоянных покупателях предоставил заказчик, в них отражена покупательская активность при работе с сайтом магазина, выручка за временной срез и целевая категория товаров. Данные практически не имели выбросов, 3 непостоянных покупателя были исключены из выборки;
# 3) Для поиска лучшей из 4 выбранных моделей классификации был подготовлен пайплайн с подготовкой данных, а также различные параметры для поиска наиболее эффективной модели с кросс-валидацией. В качестве основной метрики была выбрана f мера, так как целевой признак распределен неравномерно;
# 4) Лучшей моделью для решения задачи оказалась SVC со стандартным набором параметров;
# 5) Для категории покупателей, с высоким шинсом снижения покупательской активности, количеством просматриваемых категорий не более 2 и уровнем выручки за последний месяц более 5000, целесообразно предложить товары их любимых категорий сопоставимого качества по меньшей стоимости, а также персонализированно предложить товары из других категорий по скидкам.
#
#     Рекомендации для заказчика:
#         * для повышения качества исследования имеет смысл предоставить динамику цен на товары по категориям за последние 3 месяца, а так же факт изменения ассортимента товаров;
#         * переработать систему подписок на сервис магазина, текущие условия вообще никак не стимулируют покупателя;
#         * повысить заинтересованность покупателя в различных категориях товаров. В представленных данным достаточно много покупателей, которых интересует только определенная категория.

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Ок, но нужно добавить, какая категория любимая для нашего сегмента.
#
# По формату вывода: здесь наша конечная задача по проекту: дать рекомендацию заказчику, основываясь на данных. Заказчик будет искать глазами именно эту рекомендацию. Поэтому я бы в общем выводе ее как-то выделил или поставил на видном месте или начал с нее.

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# **Общий вывод по проекту**
#
# Спасибо за твой проект! Эта работа также была достаточно объемной и требовала концентрации внимания. По структуре проекта, логичности действий и общему подходу все замечательно, что не может не радовать.
#
# **Отмечу положительные моменты проекта🚀**
#
# * Хорошие решения в коде, есть пояснения и аргументации.
# * Грамотная предобработка и подготовка признаков.
# * Корректное обучение моделей, использование пайплайнов.
#
#
# **На что стоит обратить внимание🤔**
#
# * Важно в исследовательском анализе рассмотреть отдельно подвыборки для клиентов со снижающейся и с постоянной активностью (делим по целевому признаку).
# * Важно перевести таргет в численный вид и дальше работать уже с прицелом именно на класс снижения активности (он будет единичкой).
# * Необходимо определить сегмент для анализа по результатам модели - вероятностям классов.
# * Рекомендую также углубить и исследование сегмента: там, где можем, смотрим на динамику в категориях товаров. Я бы посмотрел на данные в разрезе акции. Думаю, как минимум, это подтвердит наши выводы, ну и возможно как-то их уточнит.
# * Эти и остальные замечания я также написал по ходу проекта.
#
# **Желаю удачи и жду твой проект на повторное ревью!**😉
#
#
# </div>

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# **Комментарий ко второй проверке**
#
# Спасибо за доработку. Критичных комментариев нет.
#
# Если что-то пропустил или остались вопросы, напиши в телеграм @kriill
#
# Желаю удачи в дальнейшей учебе!
#
# </div>
